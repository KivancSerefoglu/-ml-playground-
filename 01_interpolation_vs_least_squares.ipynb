# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m= 6
x=np.random.randn(m)
noise=np.random.randn(m)
y= 1.2*(np.sin(2*x))+0.5+noise

plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter plot of x vs y')
plt.grid()
plt.show()

# %%
X_tilde = np.vstack([x**p for p in range(m)]).T

X_tilde_inv = np.linalg.inv(X_tilde)
w = X_tilde_inv @ y

# %%
x_grid=np.linspace(min(x),max(x))
print(x_grid)
X_tilde_grid=np.vstack([x_grid**p for p in range(m)]).T
y_grid=X_tilde_grid @ w
plt.plot(x_grid,y_grid,color='red',label='Fitted curve')
plt.scatter(x,y,color='blue',label='Data points')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial Fit to Data')
plt.legend()
plt.grid()
plt.show()
# Out:
# [-2.18290572 -2.12866626 -2.0744268  -2.02018734 -1.96594788 -1.91170842
#  -1.85746895 -1.80322949 -1.74899003 -1.69475057 -1.64051111 -1.58627165
#  -1.53203219 -1.47779272 -1.42355326 -1.3693138  -1.31507434 -1.26083488
#  -1.20659542 -1.15235596 -1.09811649 -1.04387703 -0.98963757 -0.93539811
#  -0.88115865 -0.82691919 -0.77267972 -0.71844026 -0.6642008  -0.60996134
#  -0.55572188 -0.50148242 -0.44724296 -0.39300349 -0.33876403 -0.28452457
#  -0.23028511 -0.17604565 -0.12180619 -0.06756673 -0.01332726  0.0409122
#   0.09515166  0.14939112  0.20363058  0.25787004  0.3121095   0.36634897
#   0.42058843  0.47482789]
